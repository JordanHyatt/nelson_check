# %%
import random
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd
DF = pd.DataFrame

from NelsonCheck import NelsonCheck as NC

# %%
data = [random.random() for i in range(0,500)]
data = data + [.9,.9,.8,.9,.8,.9,.8,.9,.8,.9,.8,.9,.8,.9,.8,.7]

nc = NC.NelsonCheck(data=data)#, exclude_rules=[1,2,3,5,6,7,8])

# %%
nc.plot()

# %%
NC.NelsonRule(8).desc
# Out:
# 'Eight points in a row exist, but none within 1 standard deviation of the mean, and the points are in both directions from the mean'
